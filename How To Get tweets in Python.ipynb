# %% [markdown]
# We will use 03 libraries tweepy, configparser and pandas

# %%
import tweepy
import configparser
import pandas as pd

# %%
#read configs
config = configparser.ConfigParser()
config.read('config.ini')
# Out:
# ['config.ini']

# %%
api_key = config ['twitter']['api_key']
api_key_secret=config['twitter']['api_key_secret']

access_token =config['twitter']['access_token']
access_token_secret=config['twitter']['access_token_secret']

# %%
#authentication

auth =tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token,access_token_secret)

api=tweepy.API(auth)

# %%
public_tweets = api.home_timeline()
print(public_tweets )
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000026198DAAC70>, _json={'created_at': 'Fri Apr 01 16:10:21 +0000 2022', 'id': 1509926149505306631, 'id_str': '1509926149505306631', 'text': 'RT @DeborahEmeni: That moment when you really like someone and shoot your shot and they reject you. 🙏Focus on code please', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'DeborahEmeni', 'name': 'Debs', 'id': 1029968060403396608, 'id_str': '1029968060403396608', 'indices': [3, 16]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 888585263299145728, 'id_str': '888585263299145728', 'name': 'Ibrahim', 'screen_name': 'Ibrah_Oued', 'location': 'Burkina Faso', 'description': 'Software Eng.| ML Eng.| 🧠 AI enthousiast | NLP pr
# ...

# %%
# To see the 1st tweet
print(public_tweets[0].text)
# Out:
# RT @DeborahEmeni: That moment when you really like someone and shoot your shot and they reject you. 🙏Focus on code please

# %%
# To see all the tweets:
for tweet in public_tweets: 
    print(tweet.text)
# Out:
# RT @DeborahEmeni: That moment when you really like someone and shoot your shot and they reject you. 🙏Focus on code please
# You're very welcome! 😁
#
# For all those interested in sharpening your skills in #Git and #GitHub, here's my tutorial: https://t.co/mGMxiX3Flc
# Demain, je me rendrai à #Malte pour un #voyageapostolique sur les traces de l'apôtre Paul. Ce sera l'occasion de re… https://t.co/5HAiAgYjiI
# Résister au sommeil en classe c’est plus qu’un supplice 😫
# RT @emmanutapsoba: Les 3 frontières #Mali #Niger #Burkina....l’armée malienne vient de tuer 137 terroristes venus au marché de #Menaka pour…
# Had a great time yesterday speaking at the @Docker Community All Hands event!
#
# If you missed it, the talk is now av… https://t.co/FmvYhvlXOQ
# J’éprouve de la douleur et de la honte face au rôle que plusieurs catholiques ont joué dans l'abus et le manque de… https://t.co/Bcyb6QIlQf
# ...

# %%
# To see the tweet time :
print(public_tweets[0].user.created_at)

# To see who tweeted this one:
print(public_tweets[0].user.screen_name)
# Out:
# 2017-07-22 02:23:30+00:00
# Ibrah_Oued

# %%
# We will save these data into csv file using pandas

# %%
columns=['Time', "User", 'Tweet']
data=[]

for tweet in public_tweets:
    data.append([tweet.created_at, tweet.user.screen_name, tweet.text ])

df=pd.DataFrame(data, columns= columns)
print(df)
# Out:
#                         Time             User  \
# 0  2022-04-01 16:10:21+00:00       Ibrah_Oued
# 1  2022-04-01 16:00:01+00:00   faradayacademy
# 2  2022-04-01 16:00:00+00:00      Pontifex_fr
# 3  2022-04-01 15:47:14+00:00    SereneSoulama
# 4  2022-04-01 15:45:23+00:00    callmejay2403
# 5  2022-04-01 15:13:00+00:00  python_engineer
# 6  2022-04-01 15:05:00+00:00      Pontifex_fr
# 7  2022-04-01 15:00:02+00:00      Pontifex_fr
# 8  2022-04-01 14:58:07+00:00      ItsLyaaaaaa
# 9  2022-04-01 14:17:12+00:00  python_engineer
# 10 2022-04-01 14:10:37+00:00      SalimOpines
# 11 2022-04-01 13:59:32+00:00    EuniceTapsoba
# 12 2022-04-01 13:53:58+00:00    EuniceTapsoba
# 13 2022-04-01 13:53:53+00:00    EuniceTapsoba
# 14 2022-04-01 13:34:13+00:00      BalimaLeila
# 15 2022-04-01 13:13:00+00:00  Tresor_africain
# 16 2022-04-01 13:03:33+00:00       UneVanessa
# 17 2022-04-01 12:51:17+00:00  python_engineer
# 18 2022-04-01 12:48:45+00:00       UneVanessa
# ...

# %%
# Let Saving now into csv file
df.to_csv('tweets.csv')

# %%
df.head()
# Out:
#                        Time            User  \
# 0 2022-04-01 16:10:21+00:00      Ibrah_Oued
# 1 2022-04-01 16:00:01+00:00  faradayacademy
# 2 2022-04-01 16:00:00+00:00     Pontifex_fr
# 3 2022-04-01 15:47:14+00:00   SereneSoulama
# 4 2022-04-01 15:45:23+00:00   callmejay2403
#
#                                                Tweet
# 0  RT @DeborahEmeni: That moment when you really ...
# 1  You're very welcome! 😁\n\nFor all those intere...
# 2  Demain, je me rendrai à #Malte pour un #voyage...
# 3  Résister au sommeil en classe c’est plus qu’un...
# 4  RT @emmanutapsoba: Les 3 frontières #Mali #Nig...

# %% [markdown]
# ### END
